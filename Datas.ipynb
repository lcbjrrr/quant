# %% [markdown]
# <a href="https://colab.research.google.com/github/lcbjrrr/quant/blob/master/Datas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
dados = pd.read_csv('/content/drive/My Drive/PROADlicitao - k.csv')
dados.head(2)
# Out:
#        data  N∞ do Edital  Unnamed: 2 Modalidade  \
# 0  1/1/2018            20        2018     Preg„o
# 1  1/1/2018            22        2018     Preg„o
#
#                                               Objeto      Status  \
# 0   AquisiÁ„o de aparelhos e equipamentos de ·udi...  Homologado
# 1  AquisiÁ„o de aparelhos, equipamentos e utensÌl...  Homologado
#
#    Valor estimado  Valor Homologado
# 0        58201.98          45968.65
# 1       202618.10         133754.81

# %%
dados['data'] = pd.to_datetime(dados['data'], format='%d/%M/%Y')
dados['mes'] = dados['data'].dt.month
dados.head(1)
# Out:
#                  data  N∞ do Edital  Unnamed: 2 Modalidade  \
# 0 2018-01-01 00:01:00            20        2018     Preg„o
#
#                                               Objeto      Status  \
# 0   AquisiÁ„o de aparelhos e equipamentos de ·udi...  Homologado
#
#    Valor estimado  Valor Homologado           diamesano  mes
# 0        58201.98          45968.65 2018-01-01 00:01:00    1

# %%
dados.index = dados['data'] 
dados['Valor estimado'].plot()

# %%
dados['diamesano'] = "1/" + dados['mes'].astype(str) + "/"+ dados['Unnamed: 2'].astype(str)
dados
# Out:
#                                    data  N∞ do Edital  Unnamed: 2 Modalidade  \
# data
# 2018-01-01 00:01:00 2018-01-01 00:01:00            20        2018     Preg„o
# 2018-01-01 00:01:00 2018-01-01 00:01:00            22        2018     Preg„o
# 2018-01-01 00:01:00 2018-01-01 00:01:00            23        2018     Preg„o
# 2018-01-01 00:01:00 2018-01-01 00:01:00            24        2018     Preg„o
# 2018-01-01 00:01:00 2018-01-01 00:01:00            25        2018     Preg„o
# ...                                 ...           ...         ...        ...
# 2019-01-01 00:01:00 2019-01-01 00:01:00            40        2019     Preg„o
# 2019-01-01 00:01:00 2019-01-01 00:01:00            41        2019     Preg„o
# 2019-01-01 00:01:00 2019-01-01 00:01:00            63        2019     Preg„o
# 2019-01-01 00:01:00 2019-01-01 00:01:00            65        2019     Preg„o
# 2020-01-01 00:01:00 2020-01-01 00:01:00             1        2020     Preg„o
#
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data              68 non-null     object
#  1   N∞ do Edital      68 non-null     int64
#  2   Unnamed: 2        68 non-null     int64
#  3   Modalidade        68 non-null     object
#  4   Objeto            68 non-null     object
#  5   Status            68 non-null     object
#  6   Valor estimado    68 non-null     float64
#  7   Valor Homologado  68 non-null     float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.4+ KB
