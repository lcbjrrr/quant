# %% [markdown]
# <a href="https://colab.research.google.com/github/lcbjrrr/quant/blob/master/AnaDados2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nt = {'luiz':[5,6,7],
         'joao':[8,8,8],
         'mane':[9,9,9]}
nt
# Out:
# {'joao': [8, 8, 8], 'luiz': [5, 6, 7], 'mane': [9, 9, 9]}

# %%
{'joao': [8, 8, 8], 
 'luiz': [5, 6, 7], 
 'mane': [9, 9, 9]}
# Out:
# {'joao': [8, 8, 8], 'luiz': [5, 6, 7], 'mane': [9, 9, 9]}

# %% [markdown]
# ```
# NOME	'joao'	'luiz'	'mane'
# AP1	8	5	9
# AP2	8	6	9
# AP3	8	7	9
# ```

# %%
nts = {
'NOME':[	'joao',	'luiz',	'mane'],
'AP1':[	8	,5,	9],
'AP2':[	8	,6,	9],
'AP3':[	8	,7,	9]
}
nts
# Out:
# {'AP1': [8, 5, 9],
#  'AP2': [8, 6, 9],
#  'AP3': [8, 7, 9],
#  'NOME': ['joao', 'luiz', 'mane']}

# %%
import pandas as pd
notas=pd.DataFrame(nts)
notas
# Out:
#    NOME  AP1  AP2  AP3
# 0  joao    8    8    8
# 1  luiz    5    6    7
# 2  mane    9    9    9

# %%
notas = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/quant/master/notas%20(2).csv')
notas
# Out:
#    Curso   Alunos   AP1   AP2   AP3  Nota Conceito
# 0    ADM     João   9.0   8.0   9.0   8.6        B
# 1    ADM    Maria   6.0   4.0  10.0   6.0        D
# 2    DIR     José   4.0   3.0   4.0   3.6        F
# 3    ADM    Pedro   8.0  10.0   7.0   8.6        B
# 4    ECO    Paulo   7.5   8.0   9.5   8.1        B
# 5    DIR   Esther   6.0   4.5   6.0   5.4        D
# 6    ADM  Gabriel   8.0   6.0   8.0   7.2        B
# 7    DIR   Rafael   7.5  10.0   9.5   8.9        B
# 8    ECO     Davi   6.0  10.0   7.0   7.8        B
# 9    DIR   Silvio  10.0   9.5   9.5   9.7        A
# 10   ADM    Sofia   8.0   7.0   6.0   7.2        B
# 11   ADM   Raquel   4.5   4.0   4.0   4.2        F

# %%
notas.head(3)
# Out:
#   Curso Alunos  AP1  AP2   AP3  Nota Conceito
# 0   ADM   João  9.0  8.0   9.0   8.6        B
# 1   ADM  Maria  6.0  4.0  10.0   6.0        D
# 2   DIR   José  4.0  3.0   4.0   3.6        F

# %%
notas.tail(2)
# Out:
#    Curso  Alunos  AP1  AP2  AP3  Nota Conceito
# 10   ADM   Sofia  8.0  7.0  6.0   7.2        B
# 11   ADM  Raquel  4.5  4.0  4.0   4.2        F

# %%
from google.colab import drive
#drive.mount('/content/drive')
cov = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/quant/master/covid_br%20-%20ok.csv')
cov.head()
# Out:
#   Province/State Country/Region       Lat  ...  4/18/21  4/19/21  4/20/21
# 0            NaN    Afghanistan  33.93911  ...    57793    57898    58037
# 1            NaN        Albania  41.15330  ...   129594   129694   129842
# 2            NaN        Algeria  28.03390  ...   119642   119805   119992
# 3            NaN        Andorra  42.50630  ...    12805    12805    12874
# 4            NaN         Angola -11.20270  ...    24389    24518    24661
#
# [5 rows x 459 columns]

# %%
notas['AP3']
# Out:
# 0      9.0
# 1     10.0
# 2      4.0
# 3      7.0
# 4      9.5
# 5      6.0
# 6      8.0
# 7      9.5
# 8      7.0
# 9      9.5
# 10     6.0
# 11     4.0
# Name: AP3, dtype: float64

# %%
notas['AP3'].mean()
# Out:
# 7.458333333333333

# %%
nt_final = notas['AP1']*0.4+notas['AP2']*0.4+notas['AP3']*0.2
nt_final
# Out:
# 0     8.6
# 1     6.0
# 2     3.6
# 3     8.6
# 4     8.1
# 5     5.4
# 6     7.2
# 7     8.9
# 8     7.8
# 9     9.7
# 10    7.2
# 11    4.2
# dtype: float64

# %%
notas[ ['AP1','AP2','AP3'] ]
# Out:
#      AP1   AP2   AP3
# 0    9.0   8.0   9.0
# 1    6.0   4.0  10.0
# 2    4.0   3.0   4.0
# 3    8.0  10.0   7.0
# 4    7.5   8.0   9.5
# 5    6.0   4.5   6.0
# 6    8.0   6.0   8.0
# 7    7.5  10.0   9.5
# 8    6.0  10.0   7.0
# 9   10.0   9.5   9.5
# 10   8.0   7.0   6.0
# 11   4.5   4.0   4.0

# %%
notas[notas['Curso']=='ADM']
# Out:
#    Curso   Alunos  AP1   AP2   AP3  Nota Conceito
# 0    ADM     João  9.0   8.0   9.0   8.6        B
# 1    ADM    Maria  6.0   4.0  10.0   6.0        D
# 3    ADM    Pedro  8.0  10.0   7.0   8.6        B
# 6    ADM  Gabriel  8.0   6.0   8.0   7.2        B
# 10   ADM    Sofia  8.0   7.0   6.0   7.2        B
# 11   ADM   Raquel  4.5   4.0   4.0   4.2        F

# %%
notas[notas['Nota']>=7]
# Out:
#    Curso   Alunos   AP1   AP2  AP3  Nota Conceito
# 0    ADM     João   9.0   8.0  9.0   8.6        B
# 3    ADM    Pedro   8.0  10.0  7.0   8.6        B
# 4    ECO    Paulo   7.5   8.0  9.5   8.1        B
# 6    ADM  Gabriel   8.0   6.0  8.0   7.2        B
# 7    DIR   Rafael   7.5  10.0  9.5   8.9        B
# 8    ECO     Davi   6.0  10.0  7.0   7.8        B
# 9    DIR   Silvio  10.0   9.5  9.5   9.7        A
# 10   ADM    Sofia   8.0   7.0  6.0   7.2        B

# %%
nota_por_curso=notas.groupby('Curso').mean()['Nota']
print(nota_por_curso)
nota_por_curso.plot(kind='bar')
# Out:
# Curso
# ADM    6.966667
# DIR    6.900000
# ECO    7.950000
# Name: Nota, dtype: float64

# %%
nota_por_curso=notas.groupby('Curso').count()['Nota']
print(nota_por_curso)
nota_por_curso.plot(kind='pie')
# Out:
# Curso
# ADM    6
# DIR    4
# ECO    2
# Name: Nota, dtype: int64

# %%
br = cov[cov['Country/Region']=='Brazil']
brasil = br.T[4:]
brasil.diff().rolling(14).mean().plot()
